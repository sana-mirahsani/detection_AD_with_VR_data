# %% [markdown]
# # 0. Library

# %%
import importlib
import sys
sys.path.append('../') 

from features import data_utils as du
from features import data_pipeline as dp
import paths_data as paths

# Reload
importlib.reload(du)
importlib.reload(dp)
importlib.reload(paths)
# Out:
# <module 'paths_data' from '/home/smira/myproject/detection_AD_with_VR_data/src/notebooks/../paths_data.py'>

# %% [markdown]
# # 1. Constants and paths

# %%
patient_ids = paths.patient_ids
patients_data_folder = paths.RAW_DATA_DIR
patients_data_folder_cleaned = paths.STAGE_ONE_BASIC_CLEANING

# %% [markdown]
# # 2. Cleaning process

# %%
dp.pipeline_cleaning(list_patient_id=patient_ids,
                     input_path=patients_data_folder, output_path=patients_data_folder_cleaned)
# Out:
# Starting the data cleaning pipeline...
# Processing patient ID: P001
# Cleaning OK, next patient...
# Processing patient ID: P002
# Cleaning OK, next patient...
# Processing patient ID: P003
# Cleaning OK, next patient...
# Processing patient ID: P004
# Cleaning OK, next patient...
# Processing patient ID: P005
# Cleaning OK, next patient...
# Processing patient ID: P006
# Cleaning OK, next patient...
# Processing patient ID: P007
# Cleaning OK, next patient...
# Processing patient ID: P008
# Cleaning OK, next patient...
# Processing patient ID: P009
# Cleaning OK, next patient...
# Processing patient ID: P010
# Cleaning OK, next patient...
# Processing patient ID: P011
# Cleaning OK, next patient...
# Processing patient ID: P012
# Cleaning OK, next patient...
# Processing patient ID: P013
# Cleaning OK, next patient...
# Processing patient ID: P014
# Cleaning OK, next patient...
# Processing patient ID: P015
# Cleaning OK, next patient...
# Processing patient ID: P016
# ...
