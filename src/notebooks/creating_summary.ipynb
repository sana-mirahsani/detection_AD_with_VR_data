# %%
import pandas as pd

# %%
tutorial_summary_events     = pd.read_csv('../../data/PatientsData/p001_20260502_113117/20260502_113117_01_Tutorial_events.csv')
tutorial_summary_trajectory = pd.read_csv('../../data/PatientsData/p001_20260502_113117/20260502_113117_01_Tutorial_trajectory.csv')

# %%
tutorial_summary_events
# Out:
#                                                                                         Timestamp  \
# 2026-05-02 11:31:17.628           0.000  Default    PHASE_START        NaN          NaN       NaN
# 2026-05-02 11:31:17.630           0.000  Default    PANEL_SHOWN        WelcomePanel NaN       NaN
# 2026-05-02 11:31:22.971           0.000  Default    BUTTON_HOVER_START NaN          NaN       NaN
# 2026-05-02 11:31:23.918           0.952  Default    BUTTON_HOVER_END   NaN          NaN       NaN
# 2026-05-02 11:31:26.072           3.106  Default    BUTTON_HOVER_START NaN          NaN       NaN
# ...                                                                                           ...
# --- SECTION BREAK: Completion --- NaN    NaN        NaN                NaN          NaN       NaN
# 2026-05-02 11:32:09.007           46.040 Completion SECTION_START      NaN          NaN       NaN
# ...
